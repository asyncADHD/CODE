# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.array([50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000])
y = np.array([0.00136,0.04156,0.0849,0.08462,0.10764,0.12762,0.14858,0.15296,0.17316,0.15802,0.17296,0.17432,0.19892,0.23102,0.22666,0.22752,0.24648,0.25952,0.25112,0.26534])
plt.plot(x, y)


m, b = np.polyfit(x, y, 1)

plt.plot(x, m*x + b)
